# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('데이터총합.csv')

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['obesity'], df['annual_income_per_person'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['obesity'], df['smoking'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['obesity'], df['drinking'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['obesity'], df['w_control(체중조절시도)'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['obesity'], df['nutirition(영양성분표참고)'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['obesity'], df['stressed(스트레스 자가인지도)'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['obesity'], df['depressed(우울증 느끼는비율)'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['obesity'], df['financial_independence'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['obesity'], df['total_store'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['obesity'], df['chicken'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['obesity'], df['pizza'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['obesity'], df['burger'])
plt.show()

# %%
df['store_rate'] = df['total_store']/df['total_population(2021)']

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['obesity'], df['store_rate'])
plt.show()

# %%
df['store_rate'].sort_values()
# Out:
# 128    0.000078
# 194    0.000080
# 78     0.000104
# 146    0.000122
# 220    0.000127
#          ...
# 134    0.000683
# 212    0.000731
# 172    0.001030
# 227    0.001068
# 83     0.002800
# Name: store_rate, Length: 229, dtype: float64

# %%
df2 = df.drop(83)

# %%
df2

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df2['obesity'], df2['store_rate'])
plt.show()

# %%
df.head()
# Out:
#    addr   x     y  obesity  annual_income_per_person  smoking  drinking  \
# 0  가??9   3  32.5   3157.0                      20.5     51.6      52.1
# 1    강릉  11   4.0     36.7                    3303.0     20.3      59.6
# 2    강진   1  22.0     35.6                    3140.0     19.3      43.0
# 3    거제   9  20.0     30.9                    3805.0     18.7      50.3
# 4    거창   6  15.0     28.1                    3261.0     20.7      57.6
#
#    w_control(체중조절?�도)  nutirition(?�양?�분?�참�?  stressed(?�트?�스 ?��??��???  \
# 0                86.9                    20.1                         3.5
# 1                70.9                    84.7                        30.5
# 2                55.9                    75.1                        17.2
# 3                68.8                    82.7                        21.4
# 4                61.3                    76.3                        24.3
#
#    ...  total_population(2021)  male_population  female_population  \
# ...

# %%
df = pd.read_csv('데이터총합.csv')

# %%
df.head()
# Out:
#   addr  광역시도 행정구역   x   y  obesity  annual_income_per_person  smoking  \
# 0   가평   경기도  가평군   9   3     32.5                      3157     20.5
# 1   강릉   강원도  강릉시  11   4     36.7                      3303     20.3
# 2   강진  전라남도  강진군   1  22     35.6                      3140     19.3
# 3   거제  경상남도  거제시   9  20     30.9                      3805     18.7
# 4   거창  경상남도  거창군   6  15     28.1                      3261     20.7
#
#    drinking  w_control(체중조절시도)  ...  total_population(2021)  male_population  \
# 0      51.6               52.1  ...                   62383            32137
# 1      59.6               70.9  ...                  213025           105698
# 2      43.0               55.9  ...                   34099            16514
# 3      50.3               68.8  ...                  242555           127156
# 4      57.6               61.3  ...                   61399            30116
#
#    female_population  financial_independence  total_store  chicken  pizza  \
# ...

# %%
df['sigle_rate'] = df['single_person']/df['total_population(2021)']

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['obesity'], df['sigle_rate'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['obesity'], df['brush_after_lunch'])
plt.show()

# %%
corr = df.corr()
corr
# Out:
#                                  x         y   obesity  \
# x                         1.000000 -0.151983 -0.054095
# y                        -0.151983  1.000000 -0.135532
# obesity                  -0.054095 -0.135532  1.000000
# annual_income_per_person  0.060166 -0.205854 -0.381663
# smoking                   0.114530 -0.048267  0.382990
# drinking                  0.226128 -0.212917 -0.040348
# w_control(체중조절시도)         0.087047 -0.231135 -0.126136
# nutirition(영양성분표참고)      -0.010900 -0.180597 -0.085217
# stressed(스트레스 자가인지도)     -0.102458 -0.330563  0.048541
# depressed(우울증 느끼는비율)      0.052819 -0.197857  0.158959
# total_population(2021)   -0.065826 -0.229331 -0.203871
# male_population          -0.067935 -0.226518 -0.194214
# female_population        -0.063668 -0.231902 -0.213260
# financial_independence    0.004309 -0.305988 -0.220294
# total_store              -0.031112 -0.236681 -0.158780
# chicken                   0.005171 -0.237962 -0.151925
# ...

# %%
ax = sns.heatmap(corr, annot=True, annot_kws=dict(color='g'), cmap='Blues')
plt.figure(figsize=(1000, 1000))
plt.show()
# Out:
# C:\Users\0bebe\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\0bebe\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\0bebe\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51312 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\0bebe\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51208 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\0bebe\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
normalization_df = (df - df.mean())/df.std()
normalization_df.head()
# Out:
#   addr  annual_income_per_person    burger   chicken  depressed(우울증 느끼는비율)  \
# 0  NaN                 -0.517191 -0.477357 -0.412460             -0.922397
# 1  NaN                 -0.287516  0.117149  0.476373              0.574072
# 2  NaN                 -0.543934 -0.848924 -0.916133             -0.877049
# 3  NaN                  0.502188  0.191462  0.150468              0.029902
# 4  NaN                 -0.353587 -0.848924 -0.827249             -0.922397
#
#    drinking  female_population  financial_independence  male_population  \
# 0 -0.356307          -0.739910               -0.103521        -0.722882
# 1  1.208677          -0.051692               -0.360547        -0.061312
# 2 -2.038665          -0.852954               -0.977408        -0.863388
# 3 -0.610617           0.020379                0.127802         0.131670
# 4  0.817431          -0.730651               -1.020246        -0.741058
#
#    nutirition(영양성분표참고)   obesity     pizza   smoking  store_rate  \
# ...

# %%
plt.figure(figsize=(12, 6))
plt.scatter(normalization_df['obesity'], normalization_df['annual_income_per_person'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(normalization_df['obesity'], normalization_df['depressed(우울증 느끼는비율)'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(normalization_df['obesity'], normalization_df['drinking'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(normalization_df['obesity'], normalization_df['financial_independence'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(normalization_df['obesity'], normalization_df['nutirition(영양성분표참고)'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(normalization_df['obesity'], normalization_df['smoking'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(normalization_df['obesity'], normalization_df['total_store'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(normalization_df['obesity'], normalization_df['store_rate'])
plt.show()
