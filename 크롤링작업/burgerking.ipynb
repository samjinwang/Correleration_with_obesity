# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import json

# %%
burgerking = []
cnt = 1


url_list = ['https://www.burgerking.co.kr/BKR0001.json?message=%7B%22header%22%3A%7B%22error_code%22%3A%22%22%2C%22error_text%22%3A%22%22%2C%22info_text%22%3A%22%22%2C%22login_session_id%22%3A%22%22%2C%22message_version%22%3A%22%22%2C%22result%22%3Atrue%2C%22trcode%22%3A%22BKR0001%22%2C%22ip_address%22%3A%22%22%2C%22platform%22%3A%2202%22%2C%22id_member%22%3A%22%22%2C%22auth_token%22%3A%22%22%7D%2C%22body%22%3A%7B%22addrSi%22%3A%22%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C%22%2C%22addrGu%22%3A%22%22%2C%22dirveTh%22%3A%22%22%2C%22dlvyn%22%3A%22%22%2C%22kmonYn%22%3A%22%22%2C%22kordYn%22%3A%22%22%2C%22oper24Yn%22%3A%22%22%2C%22parkingYn%22%3A%22%22%2C%22distance%22%3A%22%22%2C%22sortType%22%3A%22%22%2C%22storCoordX%22%3A%22%22%2C%22storCoordY%22%3A%22%22%2C%22storNm%22%3A%22%22%7D%7D',
            'https://www.burgerking.co.kr/BKR0001.json?message=%7B%22header%22%3A%7B%22error_code%22%3A%22%22%2C%22error_text%22%3A%22%22%2C%22info_text%22%3A%22%22%2C%22login_session_id%22%3A%22%22%2C%22message_version%22%3A%22%22%2C%22result%22%3Atrue%2C%22trcode%22%3A%22BKR0001%22%2C%22ip_address%22%3A%22%22%2C%22platform%22%3A%2202%22%2C%22id_member%22%3A%22%22%2C%22auth_token%22%3A%22%22%7D%2C%22body%22%3A%7B%22addrSi%22%3A%22%EB%B6%80%EC%82%B0%EA%B4%91%EC%97%AD%EC%8B%9C%22%2C%22addrGu%22%3A%22%22%2C%22dirveTh%22%3A%22%22%2C%22dlvyn%22%3A%22%22%2C%22kmonYn%22%3A%22%22%2C%22kordYn%22%3A%22%22%2C%22oper24Yn%22%3A%22%22%2C%22parkingYn%22%3A%22%22%2C%22distance%22%3A%22%22%2C%22sortType%22%3A%22%22%2C%22storCoordX%22%3A%22%22%2C%22storCoordY%22%3A%22%22%2C%22storNm%22%3A%22%22%7D%7D',
            'https://www.burgerking.co.kr/BKR0001.json?message=%7B%22header%22%3A%7B%22error_code%22%3A%22%22%2C%22error_text%22%3A%22%22%2C%22info_text%22%3A%22%22%2C%22login_session_id%22%3A%22%22%2C%22message_version%22%3A%22%22%2C%22result%22%3Atrue%2C%22trcode%22%3A%22BKR0001%22%2C%22ip_address%22%3A%22%22%2C%22platform%22%3A%2202%22%2C%22id_member%22%3A%22%22%2C%22auth_token%22%3A%22%22%7D%2C%22body%22%3A%7B%22addrSi%22%3A%22%EB%8C%80%EA%B5%AC%EA%B4%91%EC%97%AD%EC%8B%9C%22%2C%22addrGu%22%3A%22%22%2C%22dirveTh%22%3A%22%22%2C%22dlvyn%22%3A%22%22%2C%22kmonYn%22%3A%22%22%2C%22kordYn%22%3A%22%22%2C%22oper24Yn%22%3A%22%22%2C%22parkingYn%22%3A%22%22%2C%22distance%22%3A%22%22%2C%22sortType%22%3A%22%22%2C%22storCoordX%22%3A%22%22%2C%22storCoordY%22%3A%22%22%2C%22storNm%22%3A%22%22%7D%7D',
            'https://www.burgerking.co.kr/BKR0001.json?message=%7B%22header%22%3A%7B%22error_code%22%3A%22%22%2C%22error_text%22%3A%22%22%2C%22info_text%22%3A%22%22%2C%22login_session_id%22%3A%22%22%2C%22message_version%22%3A%22%22%2C%22result%22%3Atrue%2C%22trcode%22%3A%22BKR0001%22%2C%22ip_address%22%3A%22%22%2C%22platform%22%3A%2202%22%2C%22id_member%22%3A%22%22%2C%22auth_token%22%3A%22%22%7D%2C%22body%22%3A%7B%22addrSi%22%3A%22%EC%9D%B8%EC%B2%9C%EA%B4%91%EC%97%AD%EC%8B%9C%22%2C%22addrGu%22%3A%22%22%2C%22dirveTh%22%3A%22%22%2C%22dlvyn%22%3A%22%22%2C%22kmonYn%22%3A%22%22%2C%22kordYn%22%3A%22%22%2C%22oper24Yn%22%3A%22%22%2C%22parkingYn%22%3A%22%22%2C%22distance%22%3A%22%22%2C%22sortType%22%3A%22%22%2C%22storCoordX%22%3A%22%22%2C%22storCoordY%22%3A%22%22%2C%22storNm%22%3A%22%22%7D%7D',
            'https://www.burgerking.co.kr/BKR0001.json?message=%7B%22header%22%3A%7B%22error_code%22%3A%22%22%2C%22error_text%22%3A%22%22%2C%22info_text%22%3A%22%22%2C%22login_session_id%22%3A%22%22%2C%22message_version%22%3A%22%22%2C%22result%22%3Atrue%2C%22trcode%22%3A%22BKR0001%22%2C%22ip_address%22%3A%22%22%2C%22platform%22%3A%2202%22%2C%22id_member%22%3A%22%22%2C%22auth_token%22%3A%22%22%7D%2C%22body%22%3A%7B%22addrSi%22%3A%22%EA%B4%91%EC%A3%BC%EA%B4%91%EC%97%AD%EC%8B%9C%22%2C%22addrGu%22%3A%22%22%2C%22dirveTh%22%3A%22%22%2C%22dlvyn%22%3A%22%22%2C%22kmonYn%22%3A%22%22%2C%22kordYn%22%3A%22%22%2C%22oper24Yn%22%3A%22%22%2C%22parkingYn%22%3A%22%22%2C%22distance%22%3A%22%22%2C%22sortType%22%3A%22%22%2C%22storCoordX%22%3A%22%22%2C%22storCoordY%22%3A%22%22%2C%22storNm%22%3A%22%22%7D%7D',
            'https://www.burgerking.co.kr/BKR0001.json?message=%7B%22header%22%3A%7B%22error_code%22%3A%22%22%2C%22error_text%22%3A%22%22%2C%22info_text%22%3A%22%22%2C%22login_session_id%22%3A%22%22%2C%22message_version%22%3A%22%22%2C%22result%22%3Atrue%2C%22trcode%22%3A%22BKR0001%22%2C%22ip_address%22%3A%22%22%2C%22platform%22%3A%2202%22%2C%22id_member%22%3A%22%22%2C%22auth_token%22%3A%22%22%7D%2C%22body%22%3A%7B%22addrSi%22%3A%22%EB%8C%80%EC%A0%84%EA%B4%91%EC%97%AD%EC%8B%9C%22%2C%22addrGu%22%3A%22%22%2C%22dirveTh%22%3A%22%22%2C%22dlvyn%22%3A%22%22%2C%22kmonYn%22%3A%22%22%2C%22kordYn%22%3A%22%22%2C%22oper24Yn%22%3A%22%22%2C%22parkingYn%22%3A%22%22%2C%22distance%22%3A%22%22%2C%22sortType%22%3A%22%22%2C%22storCoordX%22%3A%22%22%2C%22storCoordY%22%3A%22%22%2C%22storNm%22%3A%22%22%7D%7D',
            'https://www.burgerking.co.kr/BKR0001.json?message=%7B%22header%22%3A%7B%22error_code%22%3A%22%22%2C%22error_text%22%3A%22%22%2C%22info_text%22%3A%22%22%2C%22login_session_id%22%3A%22%22%2C%22message_version%22%3A%22%22%2C%22result%22%3Atrue%2C%22trcode%22%3A%22BKR0001%22%2C%22ip_address%22%3A%22%22%2C%22platform%22%3A%2202%22%2C%22id_member%22%3A%22%22%2C%22auth_token%22%3A%22%22%7D%2C%22body%22%3A%7B%22addrSi%22%3A%22%EC%9A%B8%EC%82%B0%EA%B4%91%EC%97%AD%EC%8B%9C%22%2C%22addrGu%22%3A%22%22%2C%22dirveTh%22%3A%22%22%2C%22dlvyn%22%3A%22%22%2C%22kmonYn%22%3A%22%22%2C%22kordYn%22%3A%22%22%2C%22oper24Yn%22%3A%22%22%2C%22parkingYn%22%3A%22%22%2C%22distance%22%3A%22%22%2C%22sortType%22%3A%22%22%2C%22storCoordX%22%3A%22%22%2C%22storCoordY%22%3A%22%22%2C%22storNm%22%3A%22%22%7D%7D',
            'https://www.burgerking.co.kr/BKR0001.json?message=%7B%22header%22%3A%7B%22error_code%22%3A%22%22%2C%22error_text%22%3A%22%22%2C%22info_text%22%3A%22%22%2C%22login_session_id%22%3A%22%22%2C%22message_version%22%3A%22%22%2C%22result%22%3Atrue%2C%22trcode%22%3A%22BKR0001%22%2C%22ip_address%22%3A%22%22%2C%22platform%22%3A%2202%22%2C%22id_member%22%3A%22%22%2C%22auth_token%22%3A%22%22%7D%2C%22body%22%3A%7B%22addrSi%22%3A%22%EC%84%B8%EC%A2%85%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EC%8B%9C%22%2C%22addrGu%22%3A%22%22%2C%22dirveTh%22%3A%22%22%2C%22dlvyn%22%3A%22%22%2C%22kmonYn%22%3A%22%22%2C%22kordYn%22%3A%22%22%2C%22oper24Yn%22%3A%22%22%2C%22parkingYn%22%3A%22%22%2C%22distance%22%3A%22%22%2C%22sortType%22%3A%22%22%2C%22storCoordX%22%3A%22%22%2C%22storCoordY%22%3A%22%22%2C%22storNm%22%3A%22%22%7D%7D',
            'https://www.burgerking.co.kr/BKR0001.json?message=%7B%22header%22%3A%7B%22error_code%22%3A%22%22%2C%22error_text%22%3A%22%22%2C%22info_text%22%3A%22%22%2C%22login_session_id%22%3A%22%22%2C%22message_version%22%3A%22%22%2C%22result%22%3Atrue%2C%22trcode%22%3A%22BKR0001%22%2C%22ip_address%22%3A%22%22%2C%22platform%22%3A%2202%22%2C%22id_member%22%3A%22%22%2C%22auth_token%22%3A%22%22%7D%2C%22body%22%3A%7B%22addrSi%22%3A%22%EA%B2%BD%EA%B8%B0%EB%8F%84%22%2C%22addrGu%22%3A%22%22%2C%22dirveTh%22%3A%22%22%2C%22dlvyn%22%3A%22%22%2C%22kmonYn%22%3A%22%22%2C%22kordYn%22%3A%22%22%2C%22oper24Yn%22%3A%22%22%2C%22parkingYn%22%3A%22%22%2C%22distance%22%3A%22%22%2C%22sortType%22%3A%22%22%2C%22storCoordX%22%3A%22%22%2C%22storCoordY%22%3A%22%22%2C%22storNm%22%3A%22%22%7D%7D',
            'https://www.burgerking.co.kr/BKR0001.json?message=%7B%22header%22%3A%7B%22error_code%22%3A%22%22%2C%22error_text%22%3A%22%22%2C%22info_text%22%3A%22%22%2C%22login_session_id%22%3A%22%22%2C%22message_version%22%3A%22%22%2C%22result%22%3Atrue%2C%22trcode%22%3A%22BKR0001%22%2C%22ip_address%22%3A%22%22%2C%22platform%22%3A%2202%22%2C%22id_member%22%3A%22%22%2C%22auth_token%22%3A%22%22%7D%2C%22body%22%3A%7B%22addrSi%22%3A%22%EA%B0%95%EC%9B%90%EB%8F%84%22%2C%22addrGu%22%3A%22%22%2C%22dirveTh%22%3A%22%22%2C%22dlvyn%22%3A%22%22%2C%22kmonYn%22%3A%22%22%2C%22kordYn%22%3A%22%22%2C%22oper24Yn%22%3A%22%22%2C%22parkingYn%22%3A%22%22%2C%22distance%22%3A%22%22%2C%22sortType%22%3A%22%22%2C%22storCoordX%22%3A%22%22%2C%22storCoordY%22%3A%22%22%2C%22storNm%22%3A%22%22%7D%7D',
            'https://www.burgerking.co.kr/BKR0001.json?message=%7B%22header%22%3A%7B%22error_code%22%3A%22%22%2C%22error_text%22%3A%22%22%2C%22info_text%22%3A%22%22%2C%22login_session_id%22%3A%22%22%2C%22message_version%22%3A%22%22%2C%22result%22%3Atrue%2C%22trcode%22%3A%22BKR0001%22%2C%22ip_address%22%3A%22%22%2C%22platform%22%3A%2202%22%2C%22id_member%22%3A%22%22%2C%22auth_token%22%3A%22%22%7D%2C%22body%22%3A%7B%22addrSi%22%3A%22%EC%B6%A9%EC%B2%AD%EB%B6%81%EB%8F%84%22%2C%22addrGu%22%3A%22%22%2C%22dirveTh%22%3A%22%22%2C%22dlvyn%22%3A%22%22%2C%22kmonYn%22%3A%22%22%2C%22kordYn%22%3A%22%22%2C%22oper24Yn%22%3A%22%22%2C%22parkingYn%22%3A%22%22%2C%22distance%22%3A%22%22%2C%22sortType%22%3A%22%22%2C%22storCoordX%22%3A%22%22%2C%22storCoordY%22%3A%22%22%2C%22storNm%22%3A%22%22%7D%7D',
            'https://www.burgerking.co.kr/BKR0001.json?message=%7B%22header%22%3A%7B%22error_code%22%3A%22%22%2C%22error_text%22%3A%22%22%2C%22info_text%22%3A%22%22%2C%22login_session_id%22%3A%22%22%2C%22message_version%22%3A%22%22%2C%22result%22%3Atrue%2C%22trcode%22%3A%22BKR0001%22%2C%22ip_address%22%3A%22%22%2C%22platform%22%3A%2202%22%2C%22id_member%22%3A%22%22%2C%22auth_token%22%3A%22%22%7D%2C%22body%22%3A%7B%22addrSi%22%3A%22%EC%B6%A9%EC%B2%AD%EB%82%A8%EB%8F%84%22%2C%22addrGu%22%3A%22%22%2C%22dirveTh%22%3A%22%22%2C%22dlvyn%22%3A%22%22%2C%22kmonYn%22%3A%22%22%2C%22kordYn%22%3A%22%22%2C%22oper24Yn%22%3A%22%22%2C%22parkingYn%22%3A%22%22%2C%22distance%22%3A%22%22%2C%22sortType%22%3A%22%22%2C%22storCoordX%22%3A%22%22%2C%22storCoordY%22%3A%22%22%2C%22storNm%22%3A%22%22%7D%7D',
            'https://www.burgerking.co.kr/BKR0001.json?message=%7B%22header%22%3A%7B%22error_code%22%3A%22%22%2C%22error_text%22%3A%22%22%2C%22info_text%22%3A%22%22%2C%22login_session_id%22%3A%22%22%2C%22message_version%22%3A%22%22%2C%22result%22%3Atrue%2C%22trcode%22%3A%22BKR0001%22%2C%22ip_address%22%3A%22%22%2C%22platform%22%3A%2202%22%2C%22id_member%22%3A%22%22%2C%22auth_token%22%3A%22%22%7D%2C%22body%22%3A%7B%22addrSi%22%3A%22%EC%A0%84%EB%9D%BC%EB%B6%81%EB%8F%84%22%2C%22addrGu%22%3A%22%22%2C%22dirveTh%22%3A%22%22%2C%22dlvyn%22%3A%22%22%2C%22kmonYn%22%3A%22%22%2C%22kordYn%22%3A%22%22%2C%22oper24Yn%22%3A%22%22%2C%22parkingYn%22%3A%22%22%2C%22distance%22%3A%22%22%2C%22sortType%22%3A%22%22%2C%22storCoordX%22%3A%22%22%2C%22storCoordY%22%3A%22%22%2C%22storNm%22%3A%22%22%7D%7D',
            'https://www.burgerking.co.kr/BKR0001.json?message=%7B%22header%22%3A%7B%22error_code%22%3A%22%22%2C%22error_text%22%3A%22%22%2C%22info_text%22%3A%22%22%2C%22login_session_id%22%3A%22%22%2C%22message_version%22%3A%22%22%2C%22result%22%3Atrue%2C%22trcode%22%3A%22BKR0001%22%2C%22ip_address%22%3A%22%22%2C%22platform%22%3A%2202%22%2C%22id_member%22%3A%22%22%2C%22auth_token%22%3A%22%22%7D%2C%22body%22%3A%7B%22addrSi%22%3A%22%EC%A0%84%EB%9D%BC%EB%82%A8%EB%8F%84%22%2C%22addrGu%22%3A%22%22%2C%22dirveTh%22%3A%22%22%2C%22dlvyn%22%3A%22%22%2C%22kmonYn%22%3A%22%22%2C%22kordYn%22%3A%22%22%2C%22oper24Yn%22%3A%22%22%2C%22parkingYn%22%3A%22%22%2C%22distance%22%3A%22%22%2C%22sortType%22%3A%22%22%2C%22storCoordX%22%3A%22%22%2C%22storCoordY%22%3A%22%22%2C%22storNm%22%3A%22%22%7D%7D',
            'https://www.burgerking.co.kr/BKR0001.json?message=%7B%22header%22%3A%7B%22error_code%22%3A%22%22%2C%22error_text%22%3A%22%22%2C%22info_text%22%3A%22%22%2C%22login_session_id%22%3A%22%22%2C%22message_version%22%3A%22%22%2C%22result%22%3Atrue%2C%22trcode%22%3A%22BKR0001%22%2C%22ip_address%22%3A%22%22%2C%22platform%22%3A%2202%22%2C%22id_member%22%3A%22%22%2C%22auth_token%22%3A%22%22%7D%2C%22body%22%3A%7B%22addrSi%22%3A%22%EA%B2%BD%EC%83%81%EB%B6%81%EB%8F%84%22%2C%22addrGu%22%3A%22%22%2C%22dirveTh%22%3A%22%22%2C%22dlvyn%22%3A%22%22%2C%22kmonYn%22%3A%22%22%2C%22kordYn%22%3A%22%22%2C%22oper24Yn%22%3A%22%22%2C%22parkingYn%22%3A%22%22%2C%22distance%22%3A%22%22%2C%22sortType%22%3A%22%22%2C%22storCoordX%22%3A%22%22%2C%22storCoordY%22%3A%22%22%2C%22storNm%22%3A%22%22%7D%7D',
            'https://www.burgerking.co.kr/BKR0001.json?message=%7B%22header%22%3A%7B%22error_code%22%3A%22%22%2C%22error_text%22%3A%22%22%2C%22info_text%22%3A%22%22%2C%22login_session_id%22%3A%22%22%2C%22message_version%22%3A%22%22%2C%22result%22%3Atrue%2C%22trcode%22%3A%22BKR0001%22%2C%22ip_address%22%3A%22%22%2C%22platform%22%3A%2202%22%2C%22id_member%22%3A%22%22%2C%22auth_token%22%3A%22%22%7D%2C%22body%22%3A%7B%22addrSi%22%3A%22%EA%B2%BD%EC%83%81%EB%82%A8%EB%8F%84%22%2C%22addrGu%22%3A%22%22%2C%22dirveTh%22%3A%22%22%2C%22dlvyn%22%3A%22%22%2C%22kmonYn%22%3A%22%22%2C%22kordYn%22%3A%22%22%2C%22oper24Yn%22%3A%22%22%2C%22parkingYn%22%3A%22%22%2C%22distance%22%3A%22%22%2C%22sortType%22%3A%22%22%2C%22storCoordX%22%3A%22%22%2C%22storCoordY%22%3A%22%22%2C%22storNm%22%3A%22%22%7D%7D',
            'https://www.burgerking.co.kr/BKR0001.json?message=%7B%22header%22%3A%7B%22error_code%22%3A%22%22%2C%22error_text%22%3A%22%22%2C%22info_text%22%3A%22%22%2C%22login_session_id%22%3A%22%22%2C%22message_version%22%3A%22%22%2C%22result%22%3Atrue%2C%22trcode%22%3A%22BKR0001%22%2C%22ip_address%22%3A%22%22%2C%22platform%22%3A%2202%22%2C%22id_member%22%3A%22%22%2C%22auth_token%22%3A%22%22%7D%2C%22body%22%3A%7B%22addrSi%22%3A%22%EC%A0%9C%EC%A3%BC%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84%22%2C%22addrGu%22%3A%22%22%2C%22dirveTh%22%3A%22%22%2C%22dlvyn%22%3A%22%22%2C%22kmonYn%22%3A%22%22%2C%22kordYn%22%3A%22%22%2C%22oper24Yn%22%3A%22%22%2C%22parkingYn%22%3A%22%22%2C%22distance%22%3A%22%22%2C%22sortType%22%3A%22%22%2C%22storCoordX%22%3A%22%22%2C%22storCoordY%22%3A%22%22%2C%22storNm%22%3A%22%22%7D%7D'
           ]


for n in range(17):


    url = url_list[n]
    info = {

        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Safari/537.36',
        'Referer': 'https://www.burgerking.co.kr/'
    }

    response = requests.get(url, headers = info)

    data = json.loads(response.text)
    print(f'{cnt}번째 크롤링 중입니다')
    cnt += 1
    
    for i in range(len(data['body']['storeList'])):
        
        burgerking.append(data['body']['storeList'][i]['ADDR_1'])
# Out:
# 1번째 크롤링 중입니다
# 2번째 크롤링 중입니다
# 3번째 크롤링 중입니다
# 4번째 크롤링 중입니다
# 5번째 크롤링 중입니다
# 6번째 크롤링 중입니다
# 7번째 크롤링 중입니다
# 8번째 크롤링 중입니다
# 9번째 크롤링 중입니다
# 10번째 크롤링 중입니다
# 11번째 크롤링 중입니다
# 12번째 크롤링 중입니다
# 13번째 크롤링 중입니다
# 14번째 크롤링 중입니다
# 15번째 크롤링 중입니다
# 16번째 크롤링 중입니다
# 17번째 크롤링 중입니다

# %%
burgerking[:10]
# Out:
# ['서울특별시 동작구 노량진로 169',
#  '서울특별시 도봉구 노해로 389',
#  '서울특별시 영등포구 선유로 130',
#  '서울특별시 도봉구 도당로 6',
#  '서울특별시 서대문구 연세로 25',
#  '서울특별시 종로구 종로 94',
#  '서울특별시 마포구 성암로 255',
#  '서울특별시 강동구 천호대로 1012',
#  '서울특별시 도봉구 도봉로 437',
#  '서울특별시 강동구 고덕로 168']

# %%
len(burgerking)
# Out:
# 425

# %%
burgerking[0].split()
# Out:
# ['서울특별시', '동작구', '노량진로', '169']

# %%
new_burgerking = []

for i in range(len(burgerking)):
    sp = []
    sp = burgerking[i].split()
    new_burgerking.append(sp[0] + " " + sp[1])

# %%
new_burgerking
# Out:
# ['서울특별시 동작구',
#  '서울특별시 도봉구',
#  '서울특별시 영등포구',
#  '서울특별시 도봉구',
#  '서울특별시 서대문구',
#  '서울특별시 종로구',
#  '서울특별시 마포구',
#  '서울특별시 강동구',
#  '서울특별시 도봉구',
#  '서울특별시 강동구',
#  '서울특별시 강북구',
#  '서울특별시 강남구',
#  '서울특별시 송파구',
#  '서울특별시 강남구',
#  '서울특별시 구로구',
#  '서울특별시 종로구',
#  '서울특별시 강동구',
#  '서울특별시 중구',
#  '서울특별시 송파구',
#  '서울특별시 영등포구',
#  '서울특별시 동작구',
#  '서울특별시 송파구',
#  '서울특별시 구로구',
#  '서울특별시 양천구',
#  '서울특별시 중구',
#  '서울특별시 강남구',
#  '서울특별시 강남구',
#  '서울특별시 중구',
#  '서울특별시 강남구',
#  '서울특별시 강남구',
#  '서울특별시 성북구',
#  '서울특별시 동대문구',
#  '서울특별시 중구',
#  '서울특별시 관악구',
#  '서울특별시 은평구',
#  '서울특별시 광진구',
#  '서울특별시 중구',
#  '서울특별시 서대문구',
#  '서울특별시 서초구',
#  '서울특별시 영등포구',
#  '서울특별시 서대문구',
#  '서울특별시 구로구',
#  '서울특별시 강서구',
#  '서울특별시 마포구',
#  '서울특별시 마포구',
#  '서울특별시 성북구',
#  '서울특별시 강북구',
#  '서울특별시 양천구',
#  '서울특별시 성북구',
#  '서울특별시 마포구',
#  '서울특별시 은평구',
#  '서울특별시 종로구',
#  '서울특별시 중랑구',
#  '서울특별시 노원구',
#  '서울특별시 송파구',
#  '서울특별시 중구',
#  '서울특별시 관악구',
#  '서울특별시 금천구',
#  '서울특별시 중구',
#  '서울특별시 구로구',
#  '서울특별시 성동구',
#  '서울특별시 광진구',
# ...

# %%
df = pd.DataFrame(new_burgerking, columns=['addr'])

# %%
df
# Out:
#             addr
# 0      서울특별시 동작구
# 1      서울특별시 도봉구
# 2     서울특별시 영등포구
# 3      서울특별시 도봉구
# 4     서울특별시 서대문구
# ..           ...
# 420     경상남도 창원시
# 421     경상남도 진주시
# 422     경상남도 창원시
# 423     경상남도 사천시
# 424  제주특별자치도 제주시
#
# [425 rows x 1 columns]

# %%
df['category'] = np.nan
df['brand'] = np.nan
df['category'] = df['category'].fillna('햄버거')
df['brand'] = df['brand'].fillna('버거킹')

# %%
df = df[['category', 'brand', 'addr']]
df
# Out:
#     category brand         addr
# 0        햄버거   버거킹    서울특별시 동작구
# 1        햄버거   버거킹    서울특별시 도봉구
# 2        햄버거   버거킹   서울특별시 영등포구
# 3        햄버거   버거킹    서울특별시 도봉구
# 4        햄버거   버거킹   서울특별시 서대문구
# ..       ...   ...          ...
# 420      햄버거   버거킹     경상남도 창원시
# 421      햄버거   버거킹     경상남도 진주시
# 422      햄버거   버거킹     경상남도 창원시
# 423      햄버거   버거킹     경상남도 사천시
# 424      햄버거   버거킹  제주특별자치도 제주시
#
# [425 rows x 3 columns]

# %%
df.to_csv('./burgerking.csv', encoding='utf-8-sig', index = False)
