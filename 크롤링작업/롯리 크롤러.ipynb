# %%
# !pip install selenium
# Out:
# ...
#      |████████████████████████████████| 904 kB 9.4 MB/s eta 0:00:01
# ...

# %%
import numpy as np
import pandas as pd
import requests
import random
from bs4 import BeautifulSoup
import json
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time

# %%
def countyName(x):
    sp = x.split(' ')
    
    if sp[0] == '경기':
        sp[0] = '경기도'
        
    elif sp[0] == '경남':
        sp[0] = '경상남도'
        
    elif sp[0] == '경북':
        sp[0] = '경상북도'
        
    elif sp[0] == '충남':
        sp[0] = '충청남도'
        
    elif sp[0] == '충북':
        sp[0] = '충청북도'
        
    elif sp[0] == '전남':
        sp[0] = '전라남도'
        
    elif sp[0] == '전북':
        sp[0] = '전라북도'
        
    elif sp[0] == '인천':
        sp[0] = '인천광역시'
    
    elif sp[0] == '광주':
        sp[0] = '광주광역시'
    
    elif sp[0] == '대구':
        sp[0] = '대구광역시'
        
    elif sp[0] == '대전':
        sp[0] = '대전광역시'
        
    elif sp[0] == '부산':
        sp[0] = '부산광역시'
        
    elif sp[0] == '서울':
        sp[0] = '서울특별시'
        
    elif sp[0] == '울산':
        sp[0] = '울산광역시'
        
    elif sp[0] == '제주도':
        sp[0] = '제주특별자치도'
        
    elif sp[0] == '제주':
        sp[0] = '제주특별자치도'
        
    elif sp[0] == '세종':
        sp[0] = '세종특별자치시'    
        
    elif sp[0] == '세종시':
        sp[0] = '세종특별자치시'
##########################################################################        
#     elif sp[1] == '한라대학로':
#         sp[1] = '제주시'
    
    return " ".join(sp)

# %%
url = f'http://www.lotteria.com/Shop/Shop_View.asp?Page=1&PageSize=10&BlockSize=10&Idx=2000&SearchIs24H=0&SearchIsWifi=0&SearchIsDT=0&SearchIsHomeService=0&SearchIsGroupOrder=0&SearchIsEvent=0&SearchArea1=&SearchArea2=&SearchText=&SearchIsFreshChicken=0&SearchIsRiaOrder=0&StoreCode=13065'
response = requests.get(url)
html = BeautifulSoup(response.text, 'html.parser')

# %%
# Out:
# '경기도 고양시'

# %%
html.select('div.h3_box')[0].text.replace('\n','')
# Out:
# ''

# %%
df = np.array([])

for i in range(2201,4215):
    url = f'http://www.lotteria.com/Shop/Shop_View.asp?Page=1&PageSize=10&BlockSize=10&Idx={i}&SearchIs24H=0&SearchIsWifi=0&SearchIsDT=0&SearchIsHomeService=0&SearchIsGroupOrder=0&SearchIsEvent=0&SearchArea1=&SearchArea2=&SearchText=&SearchIsFreshChicken=0&SearchIsRiaOrder=0&StoreCode=13065'
    response = requests.get(url)
    html = BeautifulSoup(response.text, 'html.parser')
    jum = html.select('div.h3_box')[0].text.replace('\n','')[-4:]
    if jum != '' and jum != '(폐점)':
        df = np.append(df,'햄버거')
        df = np.append(df,'롯데리아')
        df = np.append(df," ".join(countyName(html.select('td.rt')[0].text.replace('\n','')).split(' ')[0:2]))
        print(i, '페이지 완료')
    else:
        print(i, '페이지 누락됨')
        
    np.random.seed(np.random.randint(33))
    time.sleep(np.random.randint(2))

df = pd.DataFrame(df.reshape(-1,3),columns =  [['category', 'brand', 'addr']])
df.to_csv('롯데리아.csv',index= False)
# Out:
# 2201 페이지 완료
# 2202 페이지 누락됨
# 2203 페이지 완료
# 2204 페이지 완료
# 2205 페이지 완료
# 2206 페이지 완료
# 2207 페이지 완료
# 2208 페이지 완료
# 2209 페이지 누락됨
# 2210 페이지 완료
# 2211 페이지 누락됨
# 2212 페이지 누락됨
# 2213 페이지 완료
# 2214 페이지 완료
# 2215 페이지 완료
# 2216 페이지 누락됨
# 2217 페이지 완료
# 2218 페이지 누락됨
# 2219 페이지 완료
# 2220 페이지 누락됨
# 2221 페이지 완료
# 2222 페이지 완료
# 2223 페이지 완료
# 2224 페이지 누락됨
# 2225 페이지 누락됨
# 2226 페이지 누락됨
# 2227 페이지 누락됨
# 2228 페이지 누락됨
# 2229 페이지 완료
# 2230 페이지 누락됨
# 2231 페이지 완료
# 2232 페이지 누락됨
# 2233 페이지 완료
# 2234 페이지 누락됨
# 2235 페이지 완료
# 2236 페이지 누락됨
# 2237 페이지 누락됨
# 2238 페이지 완료
# 2239 페이지 완료
# 2240 페이지 누락됨
# 2241 페이지 누락됨
# 2242 페이지 누락됨
# 2243 페이지 완료
# 2244 페이지 누락됨
# 2245 페이지 완료
# 2246 페이지 완료
# 2247 페이지 누락됨
# 2248 페이지 누락됨
# 2249 페이지 완료
# 2250 페이지 누락됨
# 2251 페이지 완료
# 2252 페이지 완료
# 2253 페이지 누락됨
# 2254 페이지 누락됨
# 2255 페이지 누락됨
# 2256 페이지 완료
# 2257 페이지 누락됨
# 2258 페이지 완료
# 2259 페이지 누락됨
# 2260 페이지 완료
# 2261 페이지 누락됨
# 2262 페이지 누락됨
# 2263 페이지 누락됨
# 2264 페이지 완료
# 2265 페이지 누락됨
# 2266 페이지 누락됨
# 2267 페이지 완료
# 2268 페이지 누락됨
# ...

# %%
df
# Out:
#      category brand       addr
# 0         햄버거  롯데리아   서울특별시 중구
# 1         햄버거  롯데리아  서울특별시 송파구
# 2         햄버거  롯데리아  서울특별시 노원구
# 3         햄버거  롯데리아  서울특별시 강동구
# 4         햄버거  롯데리아  서울특별시 은평구
# ...       ...   ...        ...
# 1464      햄버거  롯데리아    경기도 고양시
# 1465      햄버거  롯데리아  서울특별시 용산구
# 1466      햄버거  롯데리아  서울특별시 용산구
# 1467      햄버거  롯데리아  서울특별시 용산구
# 1468      햄버거  롯데리아   울산광역시 중구
#
# [1469 rows x 3 columns]
