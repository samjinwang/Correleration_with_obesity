# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import json
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time

# %%
def countyName(x):
    sp = x.split(' ')
    
    if sp[0] == '경기':
        sp[0] = '경기도'
        
    elif sp[0] == '경남':
        sp[0] = '경상남도'
        
    elif sp[0] == '경북':
        sp[0] = '경상북도'
        
    elif sp[0] == '충남':
        sp[0] = '충청남도'
        
    elif sp[0] == '충북':
        sp[0] = '충청북도'
        
    elif sp[0] == '전남':
        sp[0] = '전라남도'
        
    elif sp[0] == '전북':
        sp[0] = '전라북도'
        
    elif sp[0] == '인천':
        sp[0] = '인천광역시'
    
    elif sp[0] == '광주':
        sp[0] = '광주광역시'
    
    elif sp[0] == '대구':
        sp[0] = '대구광역시'
        
    elif sp[0] == '대전':
        sp[0] = '대전광역시'
        
    elif sp[0] == '부산':
        sp[0] = '부산광역시'
        
    elif sp[0] == '서울':
        sp[0] = '서울특별시'
        
    elif sp[0] == '울산':
        sp[0] = '울산광역시'
        
    elif sp[0] == '제주도':
        sp[0] = '제주특별자치도'
        
    elif sp[0] == '제주':
        sp[0] = '제주특별자치도'
        
    elif sp[0] == '세종':
        sp[0] = '세종특별자치시'    
        
    elif sp[0] == '세종시':
        sp[0] = '세종특별자치시'
##########################################################################        
    elif sp[1] == '한라대학로':
        sp[1] = '제주시'
    
    return " ".join(sp)

# %%
url = 'http://pizzaschool.net/findstore/'
driver = webdriver.Chrome('./chromedriver')
driver.get(url)
html = BeautifulSoup(driver.page_source, 'html.parser')

# %%
#피자스쿨
df = np.array([])
for _ in range(5):
    for i in range(10):
        df = np.append(df,'피자')
        df = np.append(df,'피자스쿨')
        df = np.append(df,html.select('span.mapcategories')[i].text.replace('지역분류: ','')+' '+html.select('div.address p')[i].text)
    driver.find_element_by_xpath('//*[@id="MapListPro0"]/div[7]/a[1]').click()
    time.sleep(0.3)
df.reshape(-1,3)
# Out:
# array([['피자', '피자스쿨', '서울 송파구 가락로 63'],
#        ['피자', '피자스쿨', '서울 송파구 송이로 93'],
#        ['피자', '피자스쿨', '서울 강서구 화곡로68길 36'],
#        ['피자', '피자스쿨', '서울 강서구 강서로 506'],
#        ['피자', '피자스쿨', '경기 남양주시 가운로2길 59'],
#        ['피자', '피자스쿨', '서울 서대문구 거북골로 120'],
#        ['피자', '피자스쿨', '경기 경기도 가평읍 읍내리 가화로 122'],
#        ['피자', '피자스쿨', '인천광역시 남동구 석산로184번길 1'],
#        ['피자', '피자스쿨', '강원도 고성군 간성읍 간성로 23'],
#        ['피자', '피자스쿨', '서울 은평구 갈현로 262'],
#        ['피자', '피자스쿨', '서울 송파구 가락로 63'],
#        ['피자', '피자스쿨', '서울 송파구 송이로 93'],
#        ['피자', '피자스쿨', '서울 강서구 화곡로68길 36'],
#        ['피자', '피자스쿨', '서울 강서구 강서로 506'],
#        ['피자', '피자스쿨', '경기 남양주시 가운로2길 59'],
#        ['피자', '피자스쿨', '서울 서대문구 거북골로 120'],
#        ['피자', '피자스쿨', '경기 경기도 가평읍 읍내리 가화로 122'],
#        ['피자', '피자스쿨', '인천광역시 남동구 석산로184번길 1'],
#        ['피자', '피자스쿨', '강원도 고성군 간성읍 간성로 23'],
#        ['피자', '피자스쿨', '서울 은평구 갈현로 262'],
#        ['피자', '피자스쿨', '서울 송파구 가락로 63'],
#        ['피자', '피자스쿨', '서울 송파구 송이로 93'],
#        ['피자', '피자스쿨', '서울 강서구 화곡로68길 36'],
#        ['피자', '피자스쿨', '서울 강서구 강서로 506'],
#        ['피자', '피자스쿨', '경기 남양주시 가운로2길 59'],
#        ['피자', '피자스쿨', '서울 서대문구 거북골로 120'],
#        ['피자', '피자스쿨', '경기 경기도 가평읍 읍내리 가화로 122'],
#        ['피자', '피자스쿨', '인천광역시 남동구 석산로184번길 1'],
#        ['피자', '피자스쿨', '강원도 고성군 간성읍 간성로 23'],
#        ['피자', '피자스쿨', '서울 은평구 갈현로 262'],
#        ['피자', '피자스쿨', '서울 송파구 가락로 63'],
#        ['피자', '피자스쿨', '서울 송파구 송이로 93'],
#        ['피자', '피자스쿨', '서울 강서구 화곡로68길 36'],
#        ['피자', '피자스쿨', '서울 강서구 강서로 506'],
#        ['피자', '피자스쿨', '경기 남양주시 가운로2길 59'],
#        ['피자', '피자스쿨', '서울 서대문구 거북골로 120'],
#        ['피자', '피자스쿨', '경기 경기도 가평읍 읍내리 가화로 122'],
#        ['피자', '피자스쿨', '인천광역시 남동구 석산로184번길 1'],
#        ['피자', '피자스쿨', '강원도 고성군 간성읍 간성로 23'],
#        ['피자', '피자스쿨', '서울 은평구 갈현로 262'],
#        ['피자', '피자스쿨', '서울 송파구 가락로 63'],
#        ['피자', '피자스쿨', '서울 송파구 송이로 93'],
#        ['피자', '피자스쿨', '서울 강서구 화곡로68길 36'],
#        ['피자', '피자스쿨', '서울 강서구 강서로 506'],
#        ['피자', '피자스쿨', '경기 남양주시 가운로2길 59'],
#        ['피자', '피자스쿨', '서울 서대문구 거북골로 120'],
#        ['피자', '피자스쿨', '경기 경기도 가평읍 읍내리 가화로 122'],
#        ['피자', '피자스쿨', '인천광역시 남동구 석산로184번길 1'],
#        ['피자', '피자스쿨', '강원도 고성군 간성읍 간성로 23'],
#        ['피자', '피자스쿨', '서울 은평구 갈현로 262']], dtype='<U32')

# %%
driver.find_element_by_xpath('//*[@id="ListContainer"]/ul/li[1]/a').click()

# %%
# Out:
# '서울 중랑구'

# %%
#피자마루
url = 'https://www.pizzamaru.co.kr/store/01/'
response = requests.get(url)
html = BeautifulSoup(response.content.decode('utf-8','replace'), 'html.parser')

i = 0
df = np.array([])
while True:
    i +=2
    try:
        df = np.append(df,'피자')
        df = np.append(df, '피자마루')
        df = np.append(df,html.select(" ".join('div.area_lst.fr li p.c6')[i].text.split()[2]) +' '+ html.select('div.area_lst.fr li p.c6')[i].text.split()[3])
    except:
        break
df = np.delete(df,len(df)-1)
df = np.delete(df,len(df)-1)
df = pd.DataFrame(df.reshape(-1,3))
df.to_csv('피자마루.csv',index= False)

# %%
# 59 쌀피자
url = 'http://www.59pizza.co.kr/brd/board.php?bo_table=store02&page=2'
info = {
    'referer': 'http://www.59pizza.co.kr/brd/board.php?bo_table=store02&page=1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Safari/537.36'
}

response = requests.post(url, headers=info)
html = BeautifulSoup(response.text,'html.parser')

df = np.array([])
i = 1
while True:
    try:
        url = f'http://www.59pizza.co.kr/brd/board.php?bo_table=store02&page={i}'
        info = {
            'referer': f'http://www.59pizza.co.kr/brd/board.php?bo_table=store02&page={i}',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Safari/537.36'
        }

        response = requests.post(url, headers=info)
        html = BeautifulSoup(response.text,'html.parser')

        for j in range(10):
            df = np.append(df,'피자')
            df = np.append(df, '59쌀피자')
            df = np.append(df,html.select('p.w_address')[j].text.split(' ')[0] + ' '+html.select('p.w_address')[j].text.split(' ')[1])

        seed = np.random.randint(22) # 시드도 난수로 만들고
        np.random.seed(seed) # 시드 생성
        a = np.random.randint(3) # 시드에서 난수 생성
        time.sleep(a)
        print(i,'페이지 크롤링완료')
        i += 1
    except:
        break
df = np.delete(df,len(df)-1)
df = np.delete(df,len(df)-1)
df = pd.DataFrame(df.reshape(-1,3))
df.to_csv('59쌀피자.csv',index= False)
# Out:
# 1 페이지 크롤링완료
# 2 페이지 크롤링완료
# 3 페이지 크롤링완료
# 4 페이지 크롤링완료
# 5 페이지 크롤링완료
# 6 페이지 크롤링완료
# 7 페이지 크롤링완료
# 8 페이지 크롤링완료
# 9 페이지 크롤링완료
# 10 페이지 크롤링완료
# 11 페이지 크롤링완료
# 12 페이지 크롤링완료
# 13 페이지 크롤링완료
# 14 페이지 크롤링완료
# 15 페이지 크롤링완료
# 16 페이지 크롤링완료
# 17 페이지 크롤링완료
# 18 페이지 크롤링완료
# 19 페이지 크롤링완료
# 20 페이지 크롤링완료
# 21 페이지 크롤링완료
# 22 페이지 크롤링완료
# 23 페이지 크롤링완료
# 24 페이지 크롤링완료
# 25 페이지 크롤링완료
# 26 페이지 크롤링완료
# 27 페이지 크롤링완료
# 28 페이지 크롤링완료
# 29 페이지 크롤링완료
# 30 페이지 크롤링완료
# 31 페이지 크롤링완료
# 32 페이지 크롤링완료
# 33 페이지 크롤링완료
# 34 페이지 크롤링완료
# 35 페이지 크롤링완료
# 36 페이지 크롤링완료
# 37 페이지 크롤링완료
# 38 페이지 크롤링완료
# 39 페이지 크롤링완료
# 40 페이지 크롤링완료
# 41 페이지 크롤링완료
# 42 페이지 크롤링완료
# 43 페이지 크롤링완료
# 44 페이지 크롤링완료
# 45 페이지 크롤링완료
# 46 페이지 크롤링완료

# %%
i = 0
while True:
    try:
        url = f'http://pncg.co.kr/page/sub3_1.html?offset={i}&se_type=&se_content=&sido=&gugun=&dong=&cs_group=&cs_home=&cs_wi=&cs_kind=Y&cs_hole='
        info = {
            'referer': 'http://pncg.co.kr/page/sub3_1.html?offset=0&se_type=&se_content=&sido=&gugun=&dong=&cs_group=&cs_home=&cs_wi=&cs_kind=Y&cs_hole=',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Safari/537.36'
        }

        

        for j in range(0,40,2):
            df = np.append(df,'피자')
            df = np.append(df, '피자나라 치킨공주')
            df = np.append(df,countyName(" ".join(html.select('td.l')[j].text.replace('  ', ' ').split(' ')[0:2])))

        seed = np.random.randint(15) # 시드도 난수로 만들고
        np.random.seed(seed) # 시드 생성
        a = np.random.randint(2) # 시드에서 난수 생성
        time.sleep(a)
        print(i,'페이지 크롤링완료')
        i += 20
    except:
        break
df = np.delete(df,len(df)-1)
df = np.delete(df,len(df)-1)
df = pd.DataFrame(df.reshape(-1,3))
df.to_csv('피자나라 치킨공주.csv',index= False)
# Out:
# 0 페이지 크롤링완료
# 20 페이지 크롤링완료
# 40 페이지 크롤링완료
# 60 페이지 크롤링완료
# 80 페이지 크롤링완료
# 100 페이지 크롤링완료
# 120 페이지 크롤링완료
# 140 페이지 크롤링완료
# 160 페이지 크롤링완료
# 180 페이지 크롤링완료
# 200 페이지 크롤링완료
# 220 페이지 크롤링완료
# 240 페이지 크롤링완료
# 260 페이지 크롤링완료
# 280 페이지 크롤링완료
# 300 페이지 크롤링완료
# 320 페이지 크롤링완료
# 340 페이지 크롤링완료
# 360 페이지 크롤링완료
# 380 페이지 크롤링완료
# 400 페이지 크롤링완료
# 420 페이지 크롤링완료
# 440 페이지 크롤링완료
# 460 페이지 크롤링완료
# 480 페이지 크롤링완료
# 500 페이지 크롤링완료
# 520 페이지 크롤링완료
# 540 페이지 크롤링완료
# 560 페이지 크롤링완료
# 580 페이지 크롤링완료
# 600 페이지 크롤링완료
# 620 페이지 크롤링완료
# 640 페이지 크롤링완료
# 660 페이지 크롤링완료
# 680 페이지 크롤링완료
# 700 페이지 크롤링완료
# 720 페이지 크롤링완료
# 740 페이지 크롤링완료
# 760 페이지 크롤링완료
# 780 페이지 크롤링완료
# 800 페이지 크롤링완료
# 820 페이지 크롤링완료
# 840 페이지 크롤링완료
# 860 페이지 크롤링완료
# 880 페이지 크롤링완료
# 900 페이지 크롤링완료
# 920 페이지 크롤링완료
# 940 페이지 크롤링완료
# 960 페이지 크롤링완료
# 980 페이지 크롤링완료
# 1000 페이지 크롤링완료
# 1020 페이지 크롤링완료
# 1040 페이지 크롤링완료
# 1060 페이지 크롤링완료
# 1080 페이지 크롤링완료
# 1100 페이지 크롤링완료
# 1120 페이지 크롤링완료
# 1140 페이지 크롤링완료
# 1160 페이지 크롤링완료
# 1180 페이지 크롤링완료
# 1200 페이지 크롤링완료
# 1220 페이지 크롤링완료
# 1240 페이지 크롤링완료
# 1260 페이지 크롤링완료
# 1280 페이지 크롤링완료
# 1300 페이지 크롤링완료
# 1320 페이지 크롤링완료
# 1340 페이지 크롤링완료
# 1360 페이지 크롤링완료
# 1380 페이지 크롤링완료
# 1400 페이지 크롤링완료
# 1420 페이지 크롤링완료
# 1440 페이지 크롤링완료
# 1460 페이지 크롤링완료
# 1480 페이지 크롤링완료
# 1500 페이지 크롤링완료
# 1520 페이지 크롤링완료
# 1540 페이지 크롤링완료
# 1560 페이지 크롤링완료
# 1580 페이지 크롤링완료
# 1600 페이지 크롤링완료
# 1620 페이지 크롤링완료
# 1640 페이지 크롤링완료
# 1660 페이지 크롤링완료
# 1680 페이지 크롤링완료
# 1700 페이지 크롤링완료
# 1720 페이지 크롤링완료
# 1740 페이지 크롤링완료
# 1760 페이지 크롤링완료
# 1780 페이지 크롤링완료
# 1800 페이지 크롤링완료
# 1820 페이지 크롤링완료
# 1840 페이지 크롤링완료
# 1860 페이지 크롤링완료
# 1880 페이지 크롤링완료
# 1900 페이지 크롤링완료
# 1920 페이지 크롤링완료
# 1940 페이지 크롤링완료
# 1960 페이지 크롤링완료
# 1980 페이지 크롤링완료
# 2000 페이지 크롤링완료
# 2020 페이지 크롤링완료
# 2040 페이지 크롤링완료
# 2060 페이지 크롤링완료
# 2080 페이지 크롤링완료
# 2100 페이지 크롤링완료
# 2120 페이지 크롤링완료
# 2140 페이지 크롤링완료
# 2160 페이지 크롤링완료
# 2180 페이지 크롤링완료
# 2200 페이지 크롤링완료
# 2220 페이지 크롤링완료
# 2240 페이지 크롤링완료
# 2260 페이지 크롤링완료
# 2280 페이지 크롤링완료
# 2300 페이지 크롤링완료
# 2320 페이지 크롤링완료
# 2340 페이지 크롤링완료
# 2360 페이지 크롤링완료
# 2380 페이지 크롤링완료
# 2400 페이지 크롤링완료
# 2420 페이지 크롤링완료
# 2440 페이지 크롤링완료
# 2460 페이지 크롤링완료
# 2480 페이지 크롤링완료
# 2500 페이지 크롤링완료
# 2520 페이지 크롤링완료
# 2540 페이지 크롤링완료
# 2560 페이지 크롤링완료
# 2580 페이지 크롤링완료
# 2600 페이지 크롤링완료
# 2620 페이지 크롤링완료
# 2640 페이지 크롤링완료
# 2660 페이지 크롤링완료
# 2680 페이지 크롤링완료
# 2700 페이지 크롤링완료
# 2720 페이지 크롤링완료
# 2740 페이지 크롤링완료
# 2760 페이지 크롤링완료
# 2780 페이지 크롤링완료
# 2800 페이지 크롤링완료
# 2820 페이지 크롤링완료
# 2840 페이지 크롤링완료
# 2860 페이지 크롤링완료
# 2880 페이지 크롤링완료
# 2900 페이지 크롤링완료
# 2920 페이지 크롤링완료
# 2940 페이지 크롤링완료
# 2960 페이지 크롤링완료
# 2980 페이지 크롤링완료
# 3000 페이지 크롤링완료
# 3020 페이지 크롤링완료
# 3040 페이지 크롤링완료
# 3060 페이지 크롤링완료
# 3080 페이지 크롤링완료
# 3100 페이지 크롤링완료
# 3120 페이지 크롤링완료
# 3140 페이지 크롤링완료
# 3160 페이지 크롤링완료
# 3180 페이지 크롤링완료
# 3200 페이지 크롤링완료
# 3220 페이지 크롤링완료
# 3240 페이지 크롤링완료
# 3260 페이지 크롤링완료
# 3280 페이지 크롤링완료
# 3300 페이지 크롤링완료
# 3320 페이지 크롤링완료
# 3340 페이지 크롤링완료
# 3360 페이지 크롤링완료
# 3380 페이지 크롤링완료
# 3400 페이지 크롤링완료
# 3420 페이지 크롤링완료
# 3440 페이지 크롤링완료
# 3460 페이지 크롤링완료
# 3480 페이지 크롤링완료
# 3500 페이지 크롤링완료
# 3520 페이지 크롤링완료
# 3540 페이지 크롤링완료
# 3560 페이지 크롤링완료
# 3580 페이지 크롤링완료
# 3600 페이지 크롤링완료
# 3620 페이지 크롤링완료
# 3640 페이지 크롤링완료
# 3660 페이지 크롤링완료
# 3680 페이지 크롤링완료
# 3700 페이지 크롤링완료
# 3720 페이지 크롤링완료
# 3740 페이지 크롤링완료
# 3760 페이지 크롤링완료
# 3780 페이지 크롤링완료
# 3800 페이지 크롤링완료
# 3820 페이지 크롤링완료
# 3840 페이지 크롤링완료
# 3860 페이지 크롤링완료
# 3880 페이지 크롤링완료
# 3900 페이지 크롤링완료
# 3920 페이지 크롤링완료
# 3940 페이지 크롤링완료
# 3960 페이지 크롤링완료
# 3980 페이지 크롤링완료
# 4000 페이지 크롤링완료
# 4020 페이지 크롤링완료
# 4040 페이지 크롤링완료
# 4060 페이지 크롤링완료
# 4080 페이지 크롤링완료
# 4100 페이지 크롤링완료
# 4120 페이지 크롤링완료
# 4140 페이지 크롤링완료
# 4160 페이지 크롤링완료
# 4180 페이지 크롤링완료
# 4200 페이지 크롤링완료
# 4220 페이지 크롤링완료
# 4240 페이지 크롤링완료
# 4260 페이지 크롤링완료
# 4280 페이지 크롤링완료
# 4300 페이지 크롤링완료
# 4320 페이지 크롤링완료
# 4340 페이지 크롤링완료
# 4360 페이지 크롤링완료
# 4380 페이지 크롤링완료
# 4400 페이지 크롤링완료
# 4420 페이지 크롤링완료
# 4440 페이지 크롤링완료
# 4460 페이지 크롤링완료
# 4480 페이지 크롤링완료
# 4500 페이지 크롤링완료
# 4520 페이지 크롤링완료
# 4540 페이지 크롤링완료
# 4560 페이지 크롤링완료
# 4580 페이지 크롤링완료
# 4600 페이지 크롤링완료
# 4620 페이지 크롤링완료
# 4640 페이지 크롤링완료
# 4660 페이지 크롤링완료
# 4680 페이지 크롤링완료
# 4700 페이지 크롤링완료
# 4720 페이지 크롤링완료
# 4740 페이지 크롤링완료
# 4760 페이지 크롤링완료
# 4780 페이지 크롤링완료
# 4800 페이지 크롤링완료
# 4820 페이지 크롤링완료
# 4840 페이지 크롤링완료
# 4860 페이지 크롤링완료
# 4880 페이지 크롤링완료
# 4900 페이지 크롤링완료
# 4920 페이지 크롤링완료
# 4940 페이지 크롤링완료
# 4960 페이지 크롤링완료
# 4980 페이지 크롤링완료
# 5000 페이지 크롤링완료
# 5020 페이지 크롤링완료
# 5040 페이지 크롤링완료
# 5060 페이지 크롤링완료
# 5080 페이지 크롤링완료
# 5100 페이지 크롤링완료
# 5120 페이지 크롤링완료
# 5140 페이지 크롤링완료
# 5160 페이지 크롤링완료
# 5180 페이지 크롤링완료
# 5200 페이지 크롤링완료
# 5220 페이지 크롤링완료
# 5240 페이지 크롤링완료
# 5260 페이지 크롤링완료
# 5280 페이지 크롤링완료
# 5300 페이지 크롤링완료
# 5320 페이지 크롤링완료
# 5340 페이지 크롤링완료
# 5360 페이지 크롤링완료
# 5380 페이지 크롤링완료
# 5400 페이지 크롤링완료
# 5420 페이지 크롤링완료
# 5440 페이지 크롤링완료
# 5460 페이지 크롤링완료
# 5480 페이지 크롤링완료
# 5500 페이지 크롤링완료
# 5520 페이지 크롤링완료
# 5540 페이지 크롤링완료
# 5560 페이지 크롤링완료
# 5580 페이지 크롤링완료
# 5600 페이지 크롤링완료
# 5620 페이지 크롤링완료
# 5640 페이지 크롤링완료
# 5660 페이지 크롤링완료
# 5680 페이지 크롤링완료
# 5700 페이지 크롤링완료
# 5720 페이지 크롤링완료
# 5740 페이지 크롤링완료
# 5760 페이지 크롤링완료
# 5780 페이지 크롤링완료
# 5800 페이지 크롤링완료
# 5820 페이지 크롤링완료
# 5840 페이지 크롤링완료
# 5860 페이지 크롤링완료
# 5880 페이지 크롤링완료
# 5900 페이지 크롤링완료
# 5920 페이지 크롤링완료
# 5940 페이지 크롤링완료
# 5960 페이지 크롤링완료
# 5980 페이지 크롤링완료
# 6000 페이지 크롤링완료
# 6020 페이지 크롤링완료
# 6040 페이지 크롤링완료
# 6060 페이지 크롤링완료
# 6080 페이지 크롤링완료
# 6100 페이지 크롤링완료
# 6120 페이지 크롤링완료
# 6140 페이지 크롤링완료
# 6160 페이지 크롤링완료
# 6180 페이지 크롤링완료
# 6200 페이지 크롤링완료
# 6220 페이지 크롤링완료
# 6240 페이지 크롤링완료
# 6260 페이지 크롤링완료
# 6280 페이지 크롤링완료
# 6300 페이지 크롤링완료
# 6320 페이지 크롤링완료
# 6340 페이지 크롤링완료
# 6360 페이지 크롤링완료
# 6380 페이지 크롤링완료
# 6400 페이지 크롤링완료
# 6420 페이지 크롤링완료
# 6440 페이지 크롤링완료
# 6460 페이지 크롤링완료
# 6480 페이지 크롤링완료
# 6500 페이지 크롤링완료
# 6520 페이지 크롤링완료
# 6540 페이지 크롤링완료
# 6560 페이지 크롤링완료
# 6580 페이지 크롤링완료
# 6600 페이지 크롤링완료
# 6620 페이지 크롤링완료
# 6640 페이지 크롤링완료
# 6660 페이지 크롤링완료
# 6680 페이지 크롤링완료
# 6700 페이지 크롤링완료
# 6720 페이지 크롤링완료
# 6740 페이지 크롤링완료
# 6760 페이지 크롤링완료
# 6780 페이지 크롤링완료
# 6800 페이지 크롤링완료
# 6820 페이지 크롤링완료
# 6840 페이지 크롤링완료
# 6860 페이지 크롤링완료
# 6880 페이지 크롤링완료
# 6900 페이지 크롤링완료
# 6920 페이지 크롤링완료
# 6940 페이지 크롤링완료
# 6960 페이지 크롤링완료
# 6980 페이지 크롤링완료
# 7000 페이지 크롤링완료
# 7020 페이지 크롤링완료
# 7040 페이지 크롤링완료
# 7060 페이지 크롤링완료
# 7080 페이지 크롤링완료
# 7100 페이지 크롤링완료
# 7120 페이지 크롤링완료
# 7140 페이지 크롤링완료
# 7160 페이지 크롤링완료
# 7180 페이지 크롤링완료
# 7200 페이지 크롤링완료
# 7220 페이지 크롤링완료
# 7240 페이지 크롤링완료
# 7260 페이지 크롤링완료
# 7280 페이지 크롤링완료
# 7300 페이지 크롤링완료
# 7320 페이지 크롤링완료
# 7340 페이지 크롤링완료
# 7360 페이지 크롤링완료
# 7380 페이지 크롤링완료
# 7400 페이지 크롤링완료
# 7420 페이지 크롤링완료
# 7440 페이지 크롤링완료
# 7460 페이지 크롤링완료
# 7480 페이지 크롤링완료
# 7500 페이지 크롤링완료
# 7520 페이지 크롤링완료
# 7540 페이지 크롤링완료
# 7560 페이지 크롤링완료
# 7580 페이지 크롤링완료
# 7600 페이지 크롤링완료
# 7620 페이지 크롤링완료
# 7640 페이지 크롤링완료
# 7660 페이지 크롤링완료
# 7680 페이지 크롤링완료
# 7700 페이지 크롤링완료
# 7720 페이지 크롤링완료
# 7740 페이지 크롤링완료
# 7760 페이지 크롤링완료
# 7780 페이지 크롤링완료
# 7800 페이지 크롤링완료
# 7820 페이지 크롤링완료
# 7840 페이지 크롤링완료
# 7860 페이지 크롤링완료
# 7880 페이지 크롤링완료
# 7900 페이지 크롤링완료
# 7920 페이지 크롤링완료
# 7940 페이지 크롤링완료
# 7960 페이지 크롤링완료
# 7980 페이지 크롤링완료
# 8000 페이지 크롤링완료
# 8020 페이지 크롤링완료
# 8040 페이지 크롤링완료
# 8060 페이지 크롤링완료
# 8080 페이지 크롤링완료
# 8100 페이지 크롤링완료
# 8120 페이지 크롤링완료
# 8140 페이지 크롤링완료
# 8160 페이지 크롤링완료
# 8180 페이지 크롤링완료
# 8200 페이지 크롤링완료
# 8220 페이지 크롤링완료
# 8240 페이지 크롤링완료
# 8260 페이지 크롤링완료
# 8280 페이지 크롤링완료
# 8300 페이지 크롤링완료
# 8320 페이지 크롤링완료
# 8340 페이지 크롤링완료
# 8360 페이지 크롤링완료
# 8380 페이지 크롤링완료
# 8400 페이지 크롤링완료
# 8420 페이지 크롤링완료
# 8440 페이지 크롤링완료
# 8460 페이지 크롤링완료
# 8480 페이지 크롤링완료
# 8500 페이지 크롤링완료
# 8520 페이지 크롤링완료
# 8540 페이지 크롤링완료
# 8560 페이지 크롤링완료
# 8580 페이지 크롤링완료
# 8600 페이지 크롤링완료
# 8620 페이지 크롤링완료
# 8640 페이지 크롤링완료
# 8660 페이지 크롤링완료
# 8680 페이지 크롤링완료
# 8700 페이지 크롤링완료
# 8720 페이지 크롤링완료
# 8740 페이지 크롤링완료
# 8760 페이지 크롤링완료
# 8780 페이지 크롤링완료
# 8800 페이지 크롤링완료
# 8820 페이지 크롤링완료
# 8840 페이지 크롤링완료
# 8860 페이지 크롤링완료
# 8880 페이지 크롤링완료
# 8900 페이지 크롤링완료
# 8920 페이지 크롤링완료
# 8940 페이지 크롤링완료
# 8960 페이지 크롤링완료
# 8980 페이지 크롤링완료
# 9000 페이지 크롤링완료
# 9020 페이지 크롤링완료
# 9040 페이지 크롤링완료
# 9060 페이지 크롤링완료
# 9080 페이지 크롤링완료
# 9100 페이지 크롤링완료
# 9120 페이지 크롤링완료
# 9140 페이지 크롤링완료
# 9160 페이지 크롤링완료
# 9180 페이지 크롤링완료
# 9200 페이지 크롤링완료
# 9220 페이지 크롤링완료
# 9240 페이지 크롤링완료
# 9260 페이지 크롤링완료
# 9280 페이지 크롤링완료
# 9300 페이지 크롤링완료
# 9320 페이지 크롤링완료
# 9340 페이지 크롤링완료
# 9360 페이지 크롤링완료
# 9380 페이지 크롤링완료
# 9400 페이지 크롤링완료
# 9420 페이지 크롤링완료
# 9440 페이지 크롤링완료
# 9460 페이지 크롤링완료
# 9480 페이지 크롤링완료
# 9500 페이지 크롤링완료
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1832/2061664862.py in <module>
#      25 df = np.delete(df,len(df)-1)
#      26 df = np.delete(df,len(df)-1)
# ---> 27 df = pd.DataFrame(df.reshape(-1,3))
#      28 df.to_csv('피자나라 치킨공주.csv',index= False)
#      29
#
# ValueError: cannot reshape array of size 28918 into shape (3)
